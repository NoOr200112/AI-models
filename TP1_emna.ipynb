# %%
import pandas as pd
data = pd.read_csv('C:/Users/DELL/Downloads/tp/Iris.csv')
print(data.columns)

data.columns = ['sepal length', 'sepal width', 'petal length', 'petal width', 'class']
data.head()
# Out:
# Index(['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')
#    sepal length  sepal width  petal length  petal width            class
# 0           5.1          3.5           1.4          0.2  Iris+AC0-setosa
# 1           4.9          3.0           1.4          0.2  Iris+AC0-setosa
# 2           4.7          3.2           1.3          0.2  Iris+AC0-setosa
# 3           4.6          3.1           1.5          0.2  Iris+AC0-setosa
# 4           5.0          3.6           1.4          0.2  Iris+AC0-setosa

# %%
from pandas.api.types import is_numeric_dtype

for col in data.columns:
    if is_numeric_dtype(data[col]):
        print('%s:' % (col))
        print('\t Mean = %.2f' % data[col].mean())
        print('\t Standard deviation = %.2f' % data[col].std())
        print('\t Minimum = %.2f' % data[col].min())
        print('\t Maximum = %.2f' % data[col].max())
# Out:
# sepal length:
# 	 Mean = 5.84
# 	 Standard deviation = 0.83
# 	 Minimum = 4.30
# 	 Maximum = 7.90
# sepal width:
# 	 Mean = 3.05
# 	 Standard deviation = 0.43
# 	 Minimum = 2.00
# 	 Maximum = 4.40
# petal length:
# 	 Mean = 3.76
# 	 Standard deviation = 1.76
# 	 Minimum = 1.00
# 	 Maximum = 6.90
# petal width:
# 	 Mean = 1.20
# 	 Standard deviation = 0.76
# 	 Minimum = 0.10
# 	 Maximum = 2.50

# %%
data['class'].value_counts()
# Out:
# Iris+AC0-setosa        50
# Iris+AC0-versicolor    50
# Iris+AC0-virginica     50
# Name: class, dtype: int64

# %%
data.describe(include='all')
# Out:
#         sepal length  sepal width  petal length  petal width            class
# count     150.000000   150.000000    150.000000   150.000000              150
# unique           NaN          NaN           NaN          NaN                3
# top              NaN          NaN           NaN          NaN  Iris+AC0-setosa
# freq             NaN          NaN           NaN          NaN               50
# mean        5.843333     3.054000      3.758667     1.198667              NaN
# std         0.828066     0.433594      1.764420     0.763161              NaN
# min         4.300000     2.000000      1.000000     0.100000              NaN
# 25%         5.100000     2.800000      1.600000     0.300000              NaN
# 50%         5.800000     3.000000      4.350000     1.300000              NaN
# 75%         6.400000     3.300000      5.100000     1.800000              NaN
# max         7.900000     4.400000      6.900000     2.500000              NaN

# %%
print('Covariance:')
data.cov()
print('Correlation:')
data.corr()
# Out:
# Covariance:
# Correlation:
#               sepal length  sepal width  petal length  petal width
# sepal length      1.000000    -0.109369      0.871754     0.817954
# sepal width      -0.109369     1.000000     -0.420516    -0.356544
# petal length      0.871754    -0.420516      1.000000     0.962757
# petal width       0.817954    -0.356544      0.962757     1.000000

# %%
# %matplotlib inline
data['sepal length'].hist(bins=8)
# Out:
# <AxesSubplot:>

# %%
data.boxplot()
# Out:
# <AxesSubplot:>

# %%
import matplotlib.pyplot as plt
fig, axes = plt.subplots(3, 2, figsize=(12,12))
index = 0
for i in range(3):
    for j in range(i+1,4):
        ax1 = int(index/2)
        ax2 = index % 2
        axes[ax1][ax2].scatter(data[data.columns[i]], data[data.columns[j]],color='red')
        axes[ax1][ax2].set_xlabel(data.columns[i])
        axes[ax1][ax2].set_ylabel(data.columns[j])
        index = index + 1

# %%
from pandas.plotting import parallel_coordinates
# %matplotlib inline
parallel_coordinates(data, 'class')
# Out:
# <AxesSubplot:>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load data
data = pd.read_csv('C:/Users/DELL/Downloads/tp/Iris.csv')
data.columns = ['sepal length', 'sepal width', 'petal length', 'petal width', 'class']

# Create boxplots for all numeric columns
plt.figure(figsize=(10, 6))
sns.boxplot(data=data)
plt.title('Boxplot of Iris Dataset Features')
plt.show()
# Out:
# C:\Users\DELL\Anaconda3\lib\site-packages\scipy\__init__.py:138: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.4)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion} is required for this version of "

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load data
data = pd.read_csv('C:/Users/DELL/Downloads/tp/Iris.csv')
data.columns = ['sepal length', 'sepal width', 'petal length', 'petal width', 'class']


# Compute correlation matrix
corr_matrix = data.corr()

# Plot heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap='Blues', linewidths=0.5)
plt.title('Correlation Matrix (Blue Palette)')
plt.show()
